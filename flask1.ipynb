# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
# ans Ans - flask framework  is web framwork allow developer to build light weight web application quicklly and easily  with flask libraries
# 1 flask framework is easy to understand the developer and the beginner
#
# 2 In the flask framework there are some part which are not alter or change but almost all the  the part of flask are open to change therefore it provide the flexibility
#
# 3  ait allow unit testing through its integrated support

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1ba21ce2-90b2-4589-9cac-701de9a60c1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ba21ce2-90b2-4589-9cac-701de9a60c1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('avichal1.png',
      width = 3000)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ad2b585a-5c69-4982-9807-3731726088e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad2b585a-5c69-4982-9807-3731726088e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('avichal2.png',
      width = 3000)

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05d8575d-1271-471f-a777-f4d3d03827ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05d8575d-1271-471f-a777-f4d3d03827ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('av1.png',
      width = 3000)

# %%
Image('av2.png',
      width = 3000)

# %%
Image('av3.png',
      width = 3000)

# %%
Image('av4.png',
      width = 3000)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-11d57117-6cb9-4a2d-be67-4d9c5e41ade6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11d57117-6cb9-4a2d-be67-4d9c5e41ade6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image('avi1.png',
      width = 3000)

# %%
Image('avi2.png',
      width = 3000)

# %% [markdown]
# Flask url_for is defined as a function that enables developers to build and generate URLs on a Flask application. As a best practice, it is the url_for function that is required to be used, as hard coding the URL in templates and view function of the Flask application tends to utilize more time during modification

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# ANS App routing is the technique used to map the specific URL with the associated function intended to perform some task. The Latest Web frameworks use the routing technique to help users remember application URLs. List the different methods to bind the URLs to their associated functions.
